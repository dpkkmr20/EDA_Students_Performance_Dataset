# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("StudentsPerformance.csv")

# %%
data.head(10)
# Out:
#    gender ethnicity parental_level_of_education         lunch  \
# 0  female   group B           bachelor's degree      standard
# 1  female   group C                some college      standard
# 2  female   group B             master's degree      standard
# 3    male   group A          associate's degree  free/reduced
# 4    male   group C                some college      standard
# 5  female   group B          associate's degree      standard
# 6  female   group B                some college      standard
# 7    male   group B                some college  free/reduced
# 8    male   group D                 high school  free/reduced
# 9  female   group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# ...

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.isnull().sum()
# Out:
# gender                         0
# ethnicity                      0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# #### No null values

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.duplicated()   #checking for dupicate records.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
sns.countplot(data=data,x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.boxplot(data['math score'],orient='h')
# Out:
# <Axes: >

# %%
sns.histplot(data['math score'])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %% [markdown]
# ### Our dataset do not contain any duplicate records

# %%
sns.countplot(data=data,x="ethnicity",orient='h')
# Out:
# <Axes: xlabel='ethnicity', ylabel='count'>

# %%
sns.countplot(data=data,y="parental_level_of_education",orient='h')
# Out:
# <Axes: xlabel='count', ylabel='parental_level_of_education'>

# %%
parental_education=data['parental_level_of_education'].value_counts()
parental_education
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental_level_of_education, dtype: int64

# %%
print("Percentage of parental level of Education")
print("------------------------------------------")

print("Percenatge of some college : ",(parental_education["some college"]/1000)*100)
print("Percenatge of associate's degree : ",(parental_education["associate's degree"]/1000)*100)
print("Percenatge of high school : ",(parental_education["high school"]/1000)*100)
print("Percenatge of some high school : ",(parental_education["some high school"]/1000)*100)
print("Percenatge of bachelor's degree: ",(parental_education["bachelor's degree"]/1000)*100)
print("Percenatge of master's degree : ",(parental_education["master's degree"]/1000)*100)

plt.title("Distribution of Parental education")
plt.pie(parental_education,autopct='%.2f%%',labels=["some college","associate's degree","high school","some high school","bachelor's degree","master's degree"])
# Out:
# Percentage of parental level of Education
# ------------------------------------------
# Percenatge of some college :  22.6
# Percenatge of associate's degree :  22.2
# Percenatge of high school :  19.6
# Percenatge of some high school :  17.9
# Percenatge of bachelor's degree:  11.799999999999999
# Percenatge of master's degree :  5.8999999999999995
# ([<matplotlib.patches.Wedge at 0x1ad85610d90>,
# ...
#  [Text(0.8341981156790161, 0.717017087521336, 'some college'),
#   Text(-0.5717990621018805, 0.939705183863221, "associate's degree"),
#   Text(-1.0543739750814827, -0.3135211646298753, 'high school'),
#   Text(-0.11383566476996158, -1.0940938905900084, 'some high school'),
#   Text(0.8112644257554884, -0.7428660925790178, "bachelor's degree"),
#   Text(1.0811581857178525, -0.20272389463327067, "master's degree")],
#  [Text(0.45501715400673604, 0.3911002295570923, '22.60%'),
#   Text(-0.31189039751011655, 0.5125664639253932, '22.20%'),
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your actual dataset)
# Assume you have a DataFrame named 'df' with the specified columns

# Create subplots for each subject
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Math Score vs. Gender
sns.barplot(data=data, x='lunch', y='math score', ax=axs[0])
axs[0].set_title('Math Score')

# Reading Score vs. Gender
sns.barplot(data=data, x='lunch', y='reading score', ax=axs[1])
axs[1].set_title('Reading Score')

# Writing Score vs. Gender
sns.barplot(data=data, x='lunch', y='writing score', ax=axs[2])
axs[2].set_title('Writing Score')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your actual dataset)
# Assume you have a DataFrame named 'df' with the specified columns

# Create subplots for each subject
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Math Score vs. Gender
sns.barplot(data=data, x='gender', y='math score', ax=axs[0])
axs[0].set_title('Math Score')

# Reading Score vs. Gender
sns.barplot(data=data, x='gender', y='reading score', ax=axs[1])
axs[1].set_title('Reading Score')

# Writing Score vs. Gender
sns.barplot(data=data, x='gender', y='writing score', ax=axs[2])
axs[2].set_title('Writing Score')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your actual dataset)
# Assume you have a DataFrame named 'df' with the specified columns

# Create subplots for each subject
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Math Score vs. Gender
sns.barplot(data=data, x='test_preparation_course', y='math score', ax=axs[0])
axs[0].set_title('Math Score')

# Reading Score vs. Gender
sns.barplot(data=data, x='test_preparation_course', y='reading score', ax=axs[1])
axs[1].set_title('Reading Score')

# Writing Score vs. Gender
sns.barplot(data=data, x='test_preparation_course', y='writing score', ax=axs[2])
axs[2].set_title('Writing Score')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data (replace with your actual dataset)
# Assume you have a DataFrame named 'df' with the specified columns

# Create subplots for each subject
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns

# Math Score vs. Gender
sns.barplot(data=data, y='parental_level_of_education', x='math score', ax=axs[0])
axs[0].set_title('Math Score')

# Reading Score vs. Gender
sns.barplot(data=data, y='parental_level_of_education', x='reading score', ax=axs[1])
axs[1].set_title('Reading Score')

# Writing Score vs. Gender
sns.barplot(data=data, y='parental_level_of_education', x='writing score', ax=axs[2])
axs[2].set_title('Writing Score')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Create a new column "total_score" containing the sum of scores for each student
data['total_score'] = data[['reading score', 'writing score', 'math score']].sum(axis=1)
data['average score']=data[['reading score',  'writing score', 'math score']].mean(axis=1)
# Display the DataFrame with the new "total_score" column

data.head(5)
# Out:
#    gender ethnicity parental_level_of_education         lunch  \
# 0  female   group B           bachelor's degree      standard
# 1  female   group C                some college      standard
# 2  female   group B             master's degree      standard
# 3    male   group A          associate's degree  free/reduced
# 4    male   group C                some college      standard
#
#   test_preparation_course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# 3          148      49.333333
# ...

# %%
sns.barplot(data=data,x='test_preparation_course',y='math score',hue='gender')
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='math score'>

# %%
sns.barplot(data=data,x='test_preparation_course',y='writing score',hue='gender')
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='writing score'>

# %%
sns.barplot(data=data,x='test_preparation_course',y='reading score',hue='gender')
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='reading score'>

# %%
sns.heatmap(pd.crosstab(data['ethnicity'],data['test_preparation_course']))
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='ethnicity'>

# %% [markdown]
# ### no features are helpful in the above heatmap

# %%
sns.barplot(data=data,x="ethnicity",y='math score')
# Out:
# <Axes: xlabel='ethnicity', ylabel='math score'>

# %%
sns.heatmap(pd.crosstab(data['ethnicity'],data['parental_level_of_education']))
# Out:
# <Axes: xlabel='parental_level_of_education', ylabel='ethnicity'>

# %%
sns.distplot(data['math score'],color='orange')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13104\3522526226.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['math score'],color='orange')
# <Axes: xlabel='math score', ylabel='Density'>

# %% [markdown]
# #### Below code written is used for the students of different ethnicity,how their scores depeds on diff features

# %%
# Assuming you have a DataFrame called 'df' containing the data
# You can filter the rows where ethnicity is 'GROUP E'
group_e_students = data[data['ethnicity'] == 'group E']

# You can then extract the parental level of education for these students
parental_education_group_e = pd.DataFrame(group_e_students['test_preparation_course'])

# Print or analyze the parental level of education for 'GROUP E' students
print(parental_education_group_e)
sns.countplot(data=group_e_students,y="parental_level_of_education")
# Out:
#     test_preparation_course
# 32                     none
# 34                     none
# 35                completed
# 44                     none
# 50                     none
# ..                      ...
# 962                    none
# 968                    none
# 987               completed
# 990               completed
# 995               completed
#
# [140 rows x 1 columns]
# <Axes: xlabel='count', ylabel='parental_level_of_education'>

# %% [markdown]
# ### Distribution of parental education

# %%
import pandas as pd

# Assuming you have a DataFrame called 'df' containing the data
# You can choose which score you want to use for ranking, e.g., 'math_score'
score_column = 'total_score'

# Sort the DataFrame by the chosen score in descending order
sorted_df = data.sort_values(by=score_column, ascending=False)

# Specify the number of top-ranking students you want to retrieve
top_rank_count = 50  # Change this number as needed

# Get the top-ranking students
top_ranking_students = sorted_df.head(top_rank_count)

# Print or analyze the top-ranking students
print(top_ranking_students)
# Out:
#      gender ethnicity parental_level_of_education         lunch  \
# 916    male   group E           bachelor's degree      standard
# 458  female   group E           bachelor's degree      standard
# 962  female   group E          associate's degree      standard
# 114  female   group E           bachelor's degree      standard
# 179  female   group D            some high school      standard
# 712  female   group D                some college      standard
# 165  female   group C           bachelor's degree      standard
# 625    male   group D                some college      standard
# 903  female   group D           bachelor's degree  free/reduced
# 149    male   group E          associate's degree  free/reduced
# 685  female   group E             master's degree      standard
# 957  female   group D             master's degree      standard
# 566  female   group E           bachelor's degree  free/reduced
# 594  female   group C           bachelor's degree      standard
# ...

# %% [markdown]
# #### Extracting toppers and failiues in the above code

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
